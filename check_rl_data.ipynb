# %%
import pandas as pd

# %%
df = pd.read_csv("/localhome/local-vennw/code/datasets/install_trocar_from_tray_realsense_rl_data/dataset_info.csv")

# %%
df[df["normalized_value"] != -1.5].min()
# Out:
# key                 success_0_0
# episode_id                    0
# frame_id                      0
# status                  success
# total_frames                138
# normalized_value           -1.0
# fold                          0
# dtype: object

# %%
df["episode_id"][(df["fold"] == 0) & (df["status"] == "success")].unique()
# Out:
# array([14, 19,  1, 23, 28, 32, 37, 41, 46, 50,  6])

# %%
df["episode_id"][(df["fold"] == 1) & (df["status"] == "success")].unique()
# Out:
# array([10, 15, 24, 29,  2, 33, 38, 42, 47, 51,  7])

# %%
df["episode_id"][(df["fold"] == 2) & (df["status"] == "success")].unique()
# Out:
# array([11, 16, 20, 25, 34, 39,  3, 43, 48, 53,  8])

# %%
df["episode_id"][(df["fold"] == 3) & (df["status"] == "success")].unique()
# Out:
# array([12, 17, 21, 26, 30, 35, 44, 49,  4, 52,  9])

# %%
df["episode_id"][(df["fold"] == 4) & (df["status"] == "success")].unique()
# Out:
# array([ 0, 13, 18, 22, 27, 31, 36, 40, 45, 54,  5])

# %%
df[df["status"] == "success"].shape
# Out:
# (8839, 7)
